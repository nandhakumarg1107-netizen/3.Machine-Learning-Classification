# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

# %%
dep=dataset[['classification_yes']]

# %%
dataset['classification_yes'].value_counts()
# Out:
# classification_yes
# True     249
# False    150
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
param_grid={'n_estimators':[10,50,100,500,1000],'criterion':['gini','entropy','log_loss'],
            'max_features':['sqrt','log2','auto']}
grid=GridSearchCV(RandomForestClassifier(),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 75 fits failed out of a total of 225.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 57 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.96985266 0.97336023 0.97336023 0.98480061 0.97340287 0.97748745
#  0.97751616 0.97352463 0.9810718  0.97736106        nan        nan
#         nan        nan        nan 0.94751936 0.98123739 0.97748402
#  0.97715404 0.97346786 0.97373408 0.97346786 0.98104724 0.97719667
#  0.98480061        nan        nan        nan        nan        nan
#  0.96625392 0.97738562 0.98088284 0.97731843 0.97346786 0.98496619
#  0.98865237 0.97715404 0.98088284 0.98088284        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# C:\Users\NANDHAKUMAR GK\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2', 'auto'],
#                          'n_estimators': [10, 50, 100, 500, 1000]},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
grid_prediction=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_prediction)

from sklearn.metrics import classification_report
clf_re=classification_report(y_test,grid_prediction)

# %%
print(cm)
# Out:
# [[50  1]
#  [ 1 81]]

# %%
print(clf_re)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98        51
#         True       0.99      0.99      0.99        82
#
#     accuracy                           0.98       133
#    macro avg       0.98      0.98      0.98       133
# weighted avg       0.98      0.98      0.98       133

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_prediction,average='weighted')
print("The F1_score value of the best Parameter{}:".format(grid.best_params_),f1_macro)
# Out:
# The F1_score value of the best Parameter{'criterion': 'log_loss', 'max_features': 'log2', 'n_estimators': 50}: 0.9849624060150376

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
# Out:
# np.float64(0.9997608799617408)

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.456422      0.044238         0.198260        0.032572
# 1        1.587356      0.063436         0.228257        0.037303
# 2        3.140177      0.031129         0.318391        0.022821
# 3       15.164677      0.264231         0.907058        0.157422
# 4       35.861094      0.373046         1.994837        0.187249
# 5        0.417210      0.049293         0.188832        0.049396
# 6        1.533212      0.134406         0.241606        0.051656
# 7        3.244547      0.234247         0.298501        0.091010
# 8       20.610446      0.326744         1.126407        0.071802
# 9       31.672040      3.752534         1.351062        0.062659
# 10       0.047370      0.010898         0.000000        0.000000
# 11       0.050829      0.023192         0.000000        0.000000
# 12       0.033636      0.017489         0.000000        0.000000
# 13       0.061260      0.052284         0.000000        0.000000
# 14       0.041165      0.025349         0.000000        0.000000
# 15       0.500413      0.042067         0.185209        0.031054
# 16       1.640142      0.093782         0.276078        0.051738
# 17       3.454236      0.213387         0.391760        0.088375
# 18      14.353001      0.224801         0.626941        0.148778
# 19      27.494693      0.190598         1.434312        0.081283
# 20       0.363083      0.028832         0.154977        0.007718
# 21       1.176256      0.179415         0.193464        0.033878
# 22       2.731998      0.064526         0.286355        0.026213
# 23      14.264371      0.292103         0.775959        0.042997
# 24      27.637110      0.441538         1.359381        0.090311
# 25       0.023529      0.016777         0.000000        0.000000
# 26       0.029409      0.019279         0.000000        0.000000
# 27       0.033381      0.020289         0.000000        0.000000
# 28       0.021558      0.009937         0.000000        0.000000
# 29       0.015316      0.007263         0.000000        0.000000
# 30       0.371833      0.035841         0.146702        0.019584
# 31       1.446303      0.046095         0.189014        0.016294
# 32       2.933334      0.079086         0.276976        0.040110
# 33      13.613296      0.255579         0.796734        0.067987
# 34      26.396365      0.823135         0.987129        0.302882
# 35       0.333391      0.025848         0.159444        0.021019
# 36       1.449088      0.055130         0.234556        0.026891
# 37       2.838784      0.039650         0.250241        0.036215
# 38      13.042548      0.121084         0.685642        0.047772
# 39      15.326100      3.590086         0.299321        0.148864
# 40       0.015835      0.007647         0.000000        0.000000
# 41       0.023760      0.016491         0.000000        0.000000
# 42       0.023287      0.015571         0.000000        0.000000
# 43       0.013319      0.005518         0.000000        0.000000
# 44       0.017181      0.006045         0.000000        0.000000
#
#    param_criterion param_max_features  param_n_estimators  \
# 0             gini               sqrt                  10
# 1             gini               sqrt                  50
# 2             gini               sqrt                 100
# 3             gini               sqrt                 500
# 4             gini               sqrt                1000
# 5             gini               log2                  10
# 6             gini               log2                  50
# 7             gini               log2                 100
# 8             gini               log2                 500
# 9             gini               log2                1000
# 10            gini               auto                  10
# 11            gini               auto                  50
# 12            gini               auto                 100
# 13            gini               auto                 500
# 14            gini               auto                1000
# 15         entropy               sqrt                  10
# 16         entropy               sqrt                  50
# 17         entropy               sqrt                 100
# 18         entropy               sqrt                 500
# 19         entropy               sqrt                1000
# 20         entropy               log2                  10
# 21         entropy               log2                  50
# 22         entropy               log2                 100
# 23         entropy               log2                 500
# 24         entropy               log2                1000
# 25         entropy               auto                  10
# 26         entropy               auto                  50
# 27         entropy               auto                 100
# 28         entropy               auto                 500
# 29         entropy               auto                1000
# 30        log_loss               sqrt                  10
# 31        log_loss               sqrt                  50
# 32        log_loss               sqrt                 100
# 33        log_loss               sqrt                 500
# 34        log_loss               sqrt                1000
# 35        log_loss               log2                  10
# 36        log_loss               log2                  50
# 37        log_loss               log2                 100
# 38        log_loss               log2                 500
# 39        log_loss               log2                1000
# 40        log_loss               auto                  10
# 41        log_loss               auto                  50
# 42        log_loss               auto                 100
# 43        log_loss               auto                 500
# 44        log_loss               auto                1000
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.981569
# 1   {'criterion': 'gini', 'max_features': 'sqrt', ...           1.000000
# 2   {'criterion': 'gini', 'max_features': 'sqrt', ...           1.000000
# 3   {'criterion': 'gini', 'max_features': 'sqrt', ...           1.000000
# 4   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.981569
# 5   {'criterion': 'gini', 'max_features': 'log2', ...           0.981569
# 6   {'criterion': 'gini', 'max_features': 'log2', ...           0.962963
# 7   {'criterion': 'gini', 'max_features': 'log2', ...           1.000000
# 8   {'criterion': 'gini', 'max_features': 'log2', ...           1.000000
# 9   {'criterion': 'gini', 'max_features': 'log2', ...           0.981569
# 10  {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 11  {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 12  {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 13  {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 14  {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 15  {'criterion': 'entropy', 'max_features': 'sqrt...           0.945100
# 16  {'criterion': 'entropy', 'max_features': 'sqrt...           0.981569
# 17  {'criterion': 'entropy', 'max_features': 'sqrt...           0.981569
# 18  {'criterion': 'entropy', 'max_features': 'sqrt...           1.000000
# 19  {'criterion': 'entropy', 'max_features': 'sqrt...           0.981569
# 20  {'criterion': 'entropy', 'max_features': 'log2...           0.981569
# 21  {'criterion': 'entropy', 'max_features': 'log2...           0.981569
# 22  {'criterion': 'entropy', 'max_features': 'log2...           1.000000
# 23  {'criterion': 'entropy', 'max_features': 'log2...           0.981569
# 24  {'criterion': 'entropy', 'max_features': 'log2...           1.000000
# 25  {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 26  {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 27  {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 28  {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 29  {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 30  {'criterion': 'log_loss', 'max_features': 'sqr...           1.000000
# 31  {'criterion': 'log_loss', 'max_features': 'sqr...           0.981569
# 32  {'criterion': 'log_loss', 'max_features': 'sqr...           1.000000
# 33  {'criterion': 'log_loss', 'max_features': 'sqr...           1.000000
# 34  {'criterion': 'log_loss', 'max_features': 'sqr...           0.981569
# 35  {'criterion': 'log_loss', 'max_features': 'log...           0.981569
# 36  {'criterion': 'log_loss', 'max_features': 'log...           1.000000
# 37  {'criterion': 'log_loss', 'max_features': 'log...           1.000000
# 38  {'criterion': 'log_loss', 'max_features': 'log...           1.000000
# 39  {'criterion': 'log_loss', 'max_features': 'log...           1.000000
# 40  {'criterion': 'log_loss', 'max_features': 'aut...                NaN
# 41  {'criterion': 'log_loss', 'max_features': 'aut...                NaN
# 42  {'criterion': 'log_loss', 'max_features': 'aut...                NaN
# 43  {'criterion': 'log_loss', 'max_features': 'aut...                NaN
#